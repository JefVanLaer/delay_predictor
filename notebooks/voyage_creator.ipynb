# %% [markdown]
# # Voyage Creator
#
# Builds a voyage dataset from AIS tracking data using `VoyageCreator` from `src/voyage_creator.py`.
#
# **Pipeline:**
# 1. Load AIS data (cargo ships, vessel_type 70–79) and port reference data
# 2. Detect individual port visits (spatial proximity + speed + gap-based splitting)
# 3. Label every ping with `current_port`, `origin_port`, and `destination_port`
# 4. Group into voyages — one voyage per sea leg between consecutive port visits

# %%
import sys
sys.path.insert(0, '..')
from pathlib import Path

import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

from src.methods import dms_to_dd
from src.voyage_creator import VoyageCreator

# %% [markdown]
# ## 1. Load data

# %%
folder = Path("../data/ais")

df_ais = pd.concat(
    [pd.read_csv(f) for f in sorted(folder.glob("ais-2025-01-0*.csv"))],
    ignore_index=True,
)

df_cargo = df_ais[df_ais["vessel_type"].between(70, 79)].copy()
df_cargo["base_date_time"] = pd.to_datetime(df_cargo["base_date_time"])
df_cargo = df_cargo.sort_values(["mmsi", "base_date_time"]).reset_index(drop=True)

print(f"Cargo ship pings : {len(df_cargo):,}")
print(f"Unique vessels   : {df_cargo['mmsi'].nunique():,}")
print(f"Date range       : {df_cargo['base_date_time'].min()} → {df_cargo['base_date_time'].max()}")
# Out:
# Cargo ship pings : 5,027,387
# Unique vessels   : 2,080
# Date range       : 2025-01-01 00:00:00 → 2025-01-09 23:59:59

# %%
df_ports = pd.read_csv("../data/ports/ports.csv")
df_ports["lat_dd"] = df_ports["latitude"].apply(dms_to_dd)
df_ports["lon_dd"] = df_ports["longitude"].apply(dms_to_dd)
df_ports["geometry"] = df_ports.apply(lambda r: Point(r["lon_dd"], r["lat_dd"]), axis=1)
gdf_ports = gpd.GeoDataFrame(df_ports, geometry="geometry", crs="EPSG:4326")

print(f"Ports loaded: {len(gdf_ports):,}")
# Out:
# Ports loaded: 657

# %% [markdown]
# ## 2. Detect port visits

# %%
creator = VoyageCreator(gdf_ports, radius_nm=10, max_speed_knots=1.5, gap_threshold_h=24)

port_visits = creator.find_port_visits(df_cargo)

print(f"Port visits    : {len(port_visits):,}")
print(f"Unique vessels : {port_visits['mmsi'].nunique():,}")
print(f"Unique ports   : {port_visits['portName'].nunique():,}")
display(port_visits.head(10))
# Out:
# Port visits    : 4,635
# Unique vessels : 1,123
# Unique ports   : 234
#         mmsi     portName          entry_time           exit_time  \
# 0  205700000       Gretna 2025-01-01 00:02:14 2025-01-05 22:45:13
# 1  205700000  New Orleans 2025-01-01 00:02:14 2025-01-05 22:45:13
# 2  207138000     Savannah 2025-01-01 00:02:15 2025-01-05 13:53:05
# 3  209277000      Convent 2025-01-01 00:01:37 2025-01-03 11:44:01
# 4  209277000    St. James 2025-01-01 00:01:37 2025-01-03 11:44:01
# 5  209277000    Destrehan 2025-01-03 14:49:07 2025-01-09 16:51:04
# 6  209277000      St Rose 2025-01-03 14:49:07 2025-01-09 16:51:04
# 7  209390000     Creosote 2025-01-08 18:03:38 2025-01-09 23:59:49
# 8  209390000    Fort Ward 2025-01-08 18:03:38 2025-01-09 23:59:49
# 9  209390000      Seattle 2025-01-08 18:03:38 2025-01-09 23:59:49
#
#    duration_hours
# 0      118.716389
# 1      118.716389
# 2      109.847222
# 3       59.706667
# 4       59.706667
# 5      146.032500
# 6      146.032500
# 7       29.936389
# 8       29.936389
# 9       29.936389

# %% [markdown]
# ## 3. Label every ping
#
# | Column | At port | At sea |
# |---|---|---|
# | `current_port` | port name | `NaN` |
# | `origin_port` | `NaN` | last port departed |
# | `destination_port` | `NaN` | next port to arrive at |

# %%
df_labeled = creator.label_pings(df_cargo, port_visits)

at_port = df_labeled["current_port"].notna().sum()
print(f"Pings at port          : {at_port:,} ({at_port / len(df_labeled) * 100:.1f}%)")
print(f"Pings at sea           : {df_labeled['current_port'].isna().sum():,}")
print(f"Pings with destination : {df_labeled['destination_port'].notna().sum():,}")

display(
    df_labeled[["mmsi", "base_date_time", "sog", "current_port", "origin_port", "destination_port"]]
    .head(20)
)
# Out:
# Pings at port          : 1,785,806 (35.5%)
# Pings at sea           : 3,241,581
# Pings with destination : 1,368,845
#          mmsi      base_date_time  sog current_port origin_port  \
# 0   205700000 2025-01-01 00:02:14  0.1       Gretna         NaN
# 1   205700000 2025-01-01 00:05:14  0.1       Gretna         NaN
# 2   205700000 2025-01-01 00:08:14  0.0       Gretna         NaN
# 3   205700000 2025-01-01 00:11:14  0.1       Gretna         NaN
# 4   205700000 2025-01-01 00:14:14  0.1       Gretna         NaN
# 5   205700000 2025-01-01 00:17:14  0.1       Gretna         NaN
# 6   205700000 2025-01-01 00:20:14  0.1       Gretna         NaN
# 7   205700000 2025-01-01 00:23:14  0.0       Gretna         NaN
# 8   205700000 2025-01-01 00:26:14  0.0       Gretna         NaN
# 9   205700000 2025-01-01 00:29:14  0.1       Gretna         NaN
# 10  205700000 2025-01-01 00:32:14  0.1       Gretna         NaN
# 11  205700000 2025-01-01 00:35:14  0.1       Gretna         NaN
# 12  205700000 2025-01-01 00:38:14  0.1       Gretna         NaN
# 13  205700000 2025-01-01 00:41:14  0.1       Gretna         NaN
# 14  205700000 2025-01-01 00:44:14  0.1       Gretna         NaN
# 15  205700000 2025-01-01 00:47:14  0.0       Gretna         NaN
# 16  205700000 2025-01-01 00:50:14  0.1       Gretna         NaN
# 17  205700000 2025-01-01 00:53:14  0.1       Gretna         NaN
# 18  205700000 2025-01-01 00:56:14  0.1       Gretna         NaN
# 19  205700000 2025-01-01 00:59:14  0.1       Gretna         NaN
#
#    destination_port
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN

# %% [markdown]
# ## 4. Build voyage records

# %%
df_labeled, df_voyages = creator.build_voyages(df_labeled, port_visits)

print(f"Voyages constructed : {len(df_voyages)}")
display(df_voyages.head(10))
# Out:
# Voyages constructed : 633
#    voyage_id       mmsi   departure_port      departure_time arrival_port  \
# 0          0  209277000        St. James 2025-01-03 11:44:01    Destrehan
# 1          1  209513000  Port Everglades 2025-01-05 23:51:49        Tampa
# 2          2  209513000            Tampa 2025-01-07 14:07:57        Tampa
# 3          3  209705000       Palm Beach 2025-01-04 22:36:09   Palm Beach
# 4          4  210234000        Deer Park 2025-01-06 16:03:08    Galveston
# 5          5  210959000      Panama City 2025-01-01 03:37:58  Panama City
# 6          6  212275000        St. James 2025-01-06 20:03:39       Gretna
# 7          7  212370000      Panama City 2025-01-02 12:12:06  Panama City
# 8          8  215181000      Gulfport SI 2025-01-05 04:30:13   Portsmouth
# 9          9  215181000          Norfolk 2025-01-07 12:24:35     Savannah
#
#          arrival_time  duration_hours  ping_count
# 0 2025-01-03 14:49:07        3.085000         162
# 1 2025-01-07 13:42:53       37.851111         946
# 2 2025-01-08 14:08:24       24.007500           0
# 3 2025-01-06 22:05:44       47.493056         307
# 4 2025-01-09 00:27:15       56.401944        1006
# 5 2025-01-02 14:13:58       34.600000           0
# 6 2025-01-07 02:02:33        5.981667         167
# 7 2025-01-08 02:23:37      134.191944         613
# 8 2025-01-06 09:29:30       28.988056         975
# 9 2025-01-09 07:03:30       42.648611        1476

# %% [markdown]
# ## 5. Explore

# %%
print("=== Voyage dataset summary ===")
print(f"Total voyages   : {len(df_voyages)}")
print(f"Unique vessels  : {df_voyages['mmsi'].nunique()}")
print(f"Unique routes   : {df_voyages.groupby(['departure_port', 'arrival_port']).ngroups}")
print()
print("Duration statistics (hours):")
display(df_voyages["duration_hours"].describe().round(1))
# Out:
# === Voyage dataset summary ===
# Total voyages   : 633
# Unique vessels  : 435
# Unique routes   : 351
#
# Duration statistics (hours):
# count    633.0
# mean      41.9
# std       35.0
# min        0.8
# 25%       11.5
# 50%       34.8
# 75%       60.3
# max      177.7
# Name: duration_hours, dtype: float64

# %%
print("Most common routes:")
display(
    df_voyages
    .groupby(["departure_port", "arrival_port"])
    .agg(count=("voyage_id", "count"), avg_duration_h=("duration_hours", "mean"))
    .reset_index()
    .sort_values("count", ascending=False)
    .head(10)
    .round(1)
)

print("\nSample sea-leg pings:")
display(
    df_labeled[df_labeled["voyage_id"].notna()]
    [["mmsi", "base_date_time", "sog", "origin_port", "destination_port", "voyage_id"]]
    .head(20)
)
# Out:
# Most common routes:
#       departure_port     arrival_port  count  avg_duration_h
# 103      Los Angeles          Alameda     15            53.5
# 142      New Orleans        Destrehan     15             3.5
# 187  Port Everglades  Port Everglades     14            78.3
# 140      New Orleans          Convent     13             6.5
# 307      Two Harbors  Sault Ste Marie     11            32.6
# 340        Wyandotte  Sault Ste Marie     10            30.6
# 247  Sault Ste Marie      Two Harbors     10            39.7
# 245  Sault Ste Marie  Sault Ste Marie     10            97.2
# 87    Indiana Harbor  Sault Ste Marie      9            42.3
# 238  Sault Ste Marie       Buffington      9            37.0
# Sample sea-leg pings:
#             mmsi      base_date_time   sog origin_port destination_port  \
# 11261  209277000 2025-01-03 11:45:03   2.3   St. James        Destrehan
# 11262  209277000 2025-01-03 11:46:04   1.9   St. James        Destrehan
# 11263  209277000 2025-01-03 11:47:09   1.7   St. James        Destrehan
# 11264  209277000 2025-01-03 11:48:10   2.1   St. James        Destrehan
# 11265  209277000 2025-01-03 11:49:27   3.7   St. James        Destrehan
# 11266  209277000 2025-01-03 11:50:37   4.7   St. James        Destrehan
# 11267  209277000 2025-01-03 11:51:47   5.8   St. James        Destrehan
# 11268  209277000 2025-01-03 11:52:57   7.5   St. James        Destrehan
# 11269  209277000 2025-01-03 11:54:06   8.8   St. James        Destrehan
# 11270  209277000 2025-01-03 11:55:17   9.8   St. James        Destrehan
# 11271  209277000 2025-01-03 11:56:26  10.6   St. James        Destrehan
# 11272  209277000 2025-01-03 11:57:32  11.5   St. James        Destrehan
# 11273  209277000 2025-01-03 11:58:34  11.8   St. James        Destrehan
# 11274  209277000 2025-01-03 11:59:37  11.8   St. James        Destrehan
# 11275  209277000 2025-01-03 12:00:04  11.7   St. James        Destrehan
# 11276  209277000 2025-01-03 12:01:05  10.8   St. James        Destrehan
# 11277  209277000 2025-01-03 12:02:06  10.2   St. James        Destrehan
# 11278  209277000 2025-01-03 12:03:26  10.8   St. James        Destrehan
# 11279  209277000 2025-01-03 12:04:38  12.0   St. James        Destrehan
# 11280  209277000 2025-01-03 12:05:47  12.8   St. James        Destrehan
#
#       voyage_id
# 11261         0
# 11262         0
# 11263         0
# 11264         0
# 11265         0
# 11266         0
# 11267         0
# 11268         0
# 11269         0
# 11270         0
# 11271         0
# 11272         0
# 11273         0
# 11274         0
# 11275         0
# 11276         0
# 11277         0
# 11278         0
# 11279         0
# 11280         0
